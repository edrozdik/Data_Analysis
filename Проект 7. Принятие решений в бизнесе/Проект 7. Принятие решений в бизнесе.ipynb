# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет еще раз!\
#     Все замечания устранены, проект принят, ты молодец!
#
# Желаю тебе успехов во всех будущих начинаниях! 🙂
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Елена, привет!
#
# Меня зовут Сергей, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом. Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div style="background:#e5e5e5; color:#000; padding:10px">
#     <b>Общее впечатление о проекте</b>
#
# Ты верно провела приоритезацию гипотез и проанализировала результаты A/B-теста. Но в проекте есть моменты, которые требуют твоего внимания и доработки.
# </div>

# %% [markdown]
# ## Приоритизация гипотез.
# В файле /datasets/hypothesis.csv 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.
#
# - **Hypothesis** — краткое описание гипотезы;
# - **Reach** — охват пользователей по 10-балльной шкале;
# - **Impact** — влияние на пользователей по 10-балльной шкале;
# - **Confidence** — уверенность в гипотезе по 10-балльной шкале;
# - **Efforts** — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# **Задача**
#
# 1) Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# 2) Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# 3) Указать, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объяснить, почему так произошло.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошо, что есть описание и цели проекта.
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Не стоит разбивать описание на 2 части, весь проект описывают в начале.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сергей, привет! спасибо, поправила.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👍
# </div>

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
import warnings
import scipy.stats as stats

# %%
hypothesis = pd.read_csv('/datasets/hypothesis.csv') #читаем файл

# %%
hypothesis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %%
#Функция получения первичной информации о датафрейме

def first_look (data):
    print('---------Первые 10 строк-----------')
    display(data.head(10))
    print('---------Последние 10 строк---------')
    display(data.tail(10))
    print('---------Типы данных---------------\n')
    display(data.info())
    print('---------Статистическая сводка---------------')
    display(data.describe())
    print('---------Пропуски-----------\n')
    display(data.isna().sum())
    print('\n---------Процент пропусков от всего датасета-----------')
    display(data.isna().mean().sort_values(ascending=False)*100)
    print('\n---------Дубликаты-----------\n')
    if data.duplicated().sum() > 0:
        print('Дубликатов: ', data.duplicated().sum())
    else:
        print('Дубликатов НЕТ')

# %%
pd.set_option('display.max_colwidth', 50)

# %%
pd.options.display.max_colwidth = 200

# %%
pd.set_option('display.expand_frame_repr', None)

# %%
hypothesis.columns = hypothesis.columns.str.lower()

# %%
hypothesis.head(9)
# Out:
#                                                                                                      hypothesis  reach  impact  confidence  efforts
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов      2       5           4       10
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар      8       3           3        8
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей      3       1           1        1
# ...

# %% [markdown]
# Значения целые, пропусков, дубликатов нет.
# Названия колонок переведем в нижний регистр.

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез.  Отсортируем их по убыванию приоритета.
#
# $$
# ICE = \frac{impact \times confidence}{efforts}
# $$

# %%
hypothesis['ICE'] = hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']

# %%
# hypothesis[['hypothesis', 'ICE']]: 
# Из датафрейма hypothesis выбираются два столбца — hypothesis и ICE. 
# Это создаёт новый датафрейм, который состоит только из этих двух столбцов.
# .sort_values(by='ICE', ascending=False): Новый датафрейм сортируется по значениям в столбце ICE. 

hypothesis_ICE = hypothesis[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False).round(2)

# %%
hypothesis_ICE
# Out:
#                                                                                                      hypothesis    ICE
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения  16.20
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей  13.33
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок  11.20
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию   8.00
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа   7.00
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов   2.00
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов   1.33
# ...

# %% [markdown]
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Гипотезы имеют длинные названия, чтобы они полностью отображались  можно установить параметр функции display(): pd.options.display.max_colwidth = число_символов (например, 400).
#
# Или использовать <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html">опции pandas</a>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   добавила код, который ты указал. А как можно сделать так, чтобы текст был не в одну строку, а в несколько? как сделать перенос?
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Теперь названия гипотез полностью видны!
#
# Использовать регулярные выражения, например `\` - с новой строки и т.п.
# </div>

# %% [markdown]
# Результат метода ICE показывает:
#
# Приоритетность задачи — задачи с более высоким ICE-значением считаются более приоритетными для выполнения, так как предполагают высокий эффект при меньших усилиях.

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.
# $$
# ICE = \frac{reach \times impact \times confidence}{efforts}
# $$

# %% [markdown]
# Фреймворк **RICE** состоит из четырёх компонент:
# **Reach** — скольких пользователей затронет изменение, которое вы хотите внести;
# **Impact** — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# **Confidence** — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# **Efforts** — сколько стоит протестировать эту гипотезу.

# %% [markdown]
# RICE - расширенная версия ICE, которая используется для приоритизации задач. Он помогает оценить, какие задачи принесут наибольшую пользу при минимальных затратах времени и ресурсов.

# %%
hypothesis['RICE'] = hypothesis['impact'] * hypothesis['reach'] * hypothesis['confidence'] / hypothesis['efforts']

# %%
hypothesis_RICE = hypothesis[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False).round(2)

# %%
hypothesis_RICE
# Out:
#                                                                                                      hypothesis   RICE
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок  112.0
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа   56.0
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей   40.0
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию   40.0
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения   16.2
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар    9.0
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов    4.0
# ...

# %% [markdown]
# Результат метода RICE показывает:
#
# Приоритет задачи: Задачи с более высоким значением RICE имеют больший приоритет для выполнения, так как они могут охватить больше пользователей, оказать более сильное влияние и требуют меньше усилий

# %% [markdown]
# ### Укажем как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясним, почему так произошло.

# %%
hypothesis.sort_values(by='RICE', ascending=False).round(2)
# Out:
#                                                                                                      hypothesis  reach  impact  confidence  efforts    ICE   RICE
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок     10       7           8        5  11.20  112.0
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3   7.00   56.0
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6  13.33   40.0
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию      5       3           8        3   8.00   40.0
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения      1       9           9        5  16.20   16.2
# ...

# %% [markdown]
# После применения метода RICE приоритизация гипотез несколько изменилась. Значительный отрыв имеет 7я гипотеза - "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок".
#
# Это произошло за счет добавления в расчет информации об охвате пользователей (reach)

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошая работа, корректно применены фреймворки и проанализированы полученные результаты.
#
#
# Результаты в единой таблице, для наглядности, можно было бы проранжировать и выделить цветом: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
#
# А в качестве визуализации изменения приоритетов можно использовать: <a href="https://datayoga.ru/tpost/zh3s62fori-sloupgraf">slope graph</a>, <a href="https://cduvallet.github.io/posts/2018/03/slopegraphs-in-python">slope graph 2</a>, <a href="https://chart-studio.plotly.com/~pcchang/224/slopegraph-spending-and-academic-performance-by-states-doc/#/">реализация на plotly</a>
#
# </div>

# %% [markdown]
# ## Анализ A/B-теста
#
# Данные для второй части
#
# **Тaблица orders**
#
# - transactionId — идентификатор заказа;
# - visitorId — идентификатор пользователя, совершившего заказ;
# - date — дата, когда был совершён заказ;
# - revenue — выручка заказа;
# - group — группа A/B-теста, в которую попал заказ.
#
# **Таблица visitors**
#
# - date — дата;
# - group — группа A/B-теста;
# - visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# Обзор и предобработка полученных данных

# %%
# чтение файла с данными и сохранение в orders
try:
    orders = pd.read_csv('/Users/imac/Downloads/orders.csv')
except:
    orders = pd.read_csv('/datasets/orders.csv')
    # чтение файла с данными и сохранение в visitors
try:
    visitors = pd.read_csv('/Users/imac/Downloads/visitors.csv')
except:
    visitors = pd.read_csv('/datasets/visitors.csv')

# %%
first_look(orders)
# Out:
# ---------Первые 10 строк-----------
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
# 5      182168103   935554773  2019-08-15     2210     B
# 6      398296753  2900797465  2019-08-15     1860     B
# 7     2626614568    78758296  2019-08-15     1044     A
# 8     1576988021   295230930  2019-08-15    13710     A
# 9     1506739906  1882260405  2019-08-15     1855     B
# ---------Последние 10 строк---------
#       transactionId   visitorId        date  revenue group
# 1187     2274188238   132143192  2019-08-14      750     A
# 1188     1692103379  1022829655  2019-08-14      112     A
# 1189     4082620617   393266494  2019-08-14    31550     B
# ...

# %% [markdown]
# Формат даты определён не корректно.

# %%
first_look(visitors)
# Out:
# ---------Первые 10 строк-----------
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
# 5  2019-08-06     A       667
# 6  2019-08-07     A       644
# 7  2019-08-08     A       610
# 8  2019-08-09     A       617
# 9  2019-08-10     A       406
# ---------Последние 10 строк---------
#           date group  visitors
# 52  2019-08-22     B       650
# 53  2019-08-23     B       546
# 54  2019-08-24     B       378
# 55  2019-08-25     B       679
# 56  2019-08-26     B       676
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718
# ---------Типы данных---------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ...

# %% [markdown]
# Формат даты также опредёлен неверно

# %%
#приведём столбцы с датой к типу datetime
orders['date'] = pd.to_datetime(orders['date'], format = '%Y-%m-%d') #перевод в дату
visitors['date'] = pd.to_datetime(visitors['date'], format = '%Y-%m-%d') #перевод в дату

# %%
#приведём к нижнему регистру
orders.columns = orders.columns.str.replace('Id', '_id')

# %%
print('Кол-во посетителей в группе А: {}'.format(visitors[visitors['group']=='A']['visitors'].sum()))
print('Кол-во посетителей в группе B: {}'.format(visitors[visitors['group']=='B']['visitors'].sum()))

purchasesA = len(orders[orders['group']=='A'])
purchasesB = len(orders[orders['group']=='B'])

print(f'Кол-во покупок в группе A: {purchasesA}')
print(f'Кол-во покупок в группе B: {purchasesB}')
# Out:
# Кол-во посетителей в группе А: 18736
# Кол-во посетителей в группе B: 18916
# Кол-во покупок в группе A: 557
# Кол-во покупок в группе B: 640

# %%
# Определяем пользователей из группы A и B
visitorsA = set(orders[orders['group'] == 'A']['visitor_id'])
visitorsB = set(orders[orders['group'] == 'B']['visitor_id'])

# Находим пересечение пользователей
visitors_intersect = visitorsA.intersection(visitorsB)

# Подсчитываем количество пересекающихся пользователей
intersect_count = len(visitors_intersect)
print(f"Количество пересекающихся пользователей: {intersect_count}")

# Выводим процент пересекающихся пользователей относительно общего числа уникальных пользователей
unique_users_count = len(orders['visitor_id'].unique())
percent_intersect = round(intersect_count / unique_users_count * 100, 2)
print(f"Процент пересекающихся пользователей составляет {percent_intersect} %")
# Out:
# Количество пересекающихся пользователей: 58
# Процент пересекающихся пользователей составляет 5.63 %

# %%
# Определяем пользователей из группы A и B
visitorsA = set(orders[orders['group'] == 'A']['visitor_id'])
visitorsB = set(orders[orders['group'] == 'B']['visitor_id'])

# Находим пересекающихся пользователей
visitors_intersect = visitorsA.intersection(visitorsB)

# Удаляем пересекающихся пользователей из таблицы orders
orders_cleaned = orders[~orders['visitor_id'].isin(visitors_intersect)]

# Проверим результат
print(f"Исходное количество записей: {len(orders)}")
print(f"Количество записей после удаления пересекающихся пользователей: {len(orders_cleaned)}")
# Out:
# Исходное количество записей: 1197
# Количество записей после удаления пересекающихся пользователей: 1016

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#
#   ❌ Еще остается не выполненным на этапе предобработки, но тем не менее важным - проверить корректность разбиения пользователей на группы - может быть есть пользователи, попавшие в обе группы? Если таковые пользователи есть, нужно их выявить и выработать стратегию работы с такими данными. Пересечение групп сильно влияет на результаты теста, если процент достаточно большой. Если есть возможность их можно удалить и посмотреть, какие результаты получаются без них, в любом случае к результатам теста придется относится осторожно.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сергей, поправила
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера v.2</b>
#
#
#   ❌ Хорошо, только мы пользователей удалили из датафрейма `orders_cleaned`, а весь дальнейший проект выполняем по датафрейму `orders`, в котором пересечение осталось.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   да, спасибо, я поправила везде `orders` на `orders_cleaned`
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Pезультаты теста они больше не искажают.
# </div>

# %% [markdown]
# ### Построим график кумулятивной выручки по группам

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = orders_cleaned[['date','group']].drop_duplicates()

# %%
ordersAggregated = datesGroups.apply(lambda x: orders_cleaned[np.logical_and(orders_cleaned['date'] <= x['date'], orders_cleaned['group'] == x['group'])]\
.agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
# Аналогично получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина: 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group']) 
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
cumulativeData.head(5)
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      23      19   142779       719
# 1 2019-08-01     B      17      17    59758       713
# 2 2019-08-02     A      42      36   234381      1338
# 3 2019-08-02     B      40      39   221801      1294
# 4 2019-08-03     A      66      60   346854      1845

# %%
# Объединим обе таблицы в одну с понятными названиями столбцов: 
datesGroups = orders_cleaned[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(lambda x: orders_cleaned[np.logical_and(orders_cleaned['date'] <= x['date'], orders_cleaned['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

print(cumulativeData.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      23      19   142779       719
# 1 2019-08-01     B      17      17    59758       713
# 2 2019-08-02     A      42      36   234381      1338
# 3 2019-08-02     B      40      39   221801      1294
# 4 2019-08-03     A      66      60   346854      1845

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.xticks(rotation=90)

plt.legend() 

# зададим описание графика
plt.legend(['Группа А', 'Группа B']) 
plt.xlabel('Дата')
plt.ylabel('Выручка') 
plt.title('Кумулятивная выручка по дням и группам A/B-тестирования')
plt.show()

# %% [markdown]
# По графику видим следующее:
#
# - группа B лидирирует на всём периоде
# - у группы B произошёл резкий рост в период с 18 на 19 августа, на это могут быть 2 причины:
# в группу попал анамально дорогой заказ
# в этот день было много заказов
# Выведем графики для группы B с изменение кол-ва заказов и выручки:

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ График построен верно и можем зафиксировать аномалию в группе В.
# </div>
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
#   ❌  Надо дооформить все графики, вывести названия и подписать оси.
#
# Чтобы при построении графика не выскакивали технические надписи вроде: `<matplotlib.legend.Legend at 0x7fb0715a2a90>` добавляй в конце вывода `plt.show();`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сергей, поправила, спасибо
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам

# %% [markdown]
# Построим графики среднего чека по группам — разделим кумулятивную выручку на кумулятивное число заказов:

# %%
#зададим размеры графика  
plt.figure(figsize=(9,5))   

#построим графики, что бы получить средний чек, разделим выручку на число заказов
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.legend()  

# зададим описание графика
plt.legend(['Группа А', 'Группа B']) 
plt.xlabel('Дата')
plt.ylabel('Средний чек') 
plt.title('Кумулятивный средний чек по дням и группам A/B-тестирования')
plt.show()

# %% [markdown]
# Вывод:
#
# В первой половине теста графики ведут себя не стабильно, есть как сильные росты, так и падения.
# на графике среднего чека анамальное значения для группы B в период с 08.17 по 08.21 уже более явное.
# к коцу периода коммулятивный средний чек группы B, выше, чем у А, но стоит отметить, что к концу периода у группы А есть тенденция к росту, а у B к снижению.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Тут так-же группа В выделяется.
# </div>

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# cтроим отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)
plt.xticks(rotation=90)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--') 


# зададим описание графика 
plt.xlabel('Дата')
plt.ylabel('Отношение') 
plt.title('Относительное изменение кумулятивного среднего чека группы B к группе A')
plt.show()

# %% [markdown]
# На графике видим резкие скачки, это может значит, что именно в пиковый дни на графике, были сделаны анамально дорогие заказы.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Верно, похоже на крупные заказы.
# </div>

# %% [markdown]
# ### Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %%
# считаем среднее количество заказов на посетителя
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()
plt.xticks(rotation=90)

# задаем масштаб осей
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), 0, 0.04])
plt.xlabel('Дата')
plt.ylabel('Количество заказов')
plt.title("Кумулятивное среднее количество заказов по группам")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# В начале теста сегмент А имел большую конверсию, затем он немного упал и установился примерно около одного значения, в отличие от сегмента В, который возрос выше сегмента А и также установился в пределах одного значения.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Группа В в лидерах.
# </div>
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Только у нас тут и далее количество заказов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Поправила, спасибо
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост конверсии группы B относительно группы A")
#plt.legend()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.15, color='grey', linestyle='--')
plt.axis([pd.to_datetime('2019-08-01', format = '%Y-%m-%d'),
             pd.to_datetime('2019-09-01', format = '%Y-%m-%d'), -0.2, 0.3])
plt.xlabel('Дата')
plt.ylabel('Конверсия')
plt.title("Относительный прирост конверсии группы В относительно группы А")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Почти с самого начала теста группа B лидирует относительно группы А. Но не стоит говорить, что она зафиксировалась возле определенной цифры, но прирост становится примерно на 15%.
#
# Построим точечный график количества заказов по пользователям.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Да, группа В выше, а еще в последней трети эксперимента наблюдается стабилизация результатов.
# </div>

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям

# %%
#создадим сводную таблицу с кол-вом закзазов для каждого пользователя 
orders_count = (
    orders_cleaned.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)

# %%
#выведем таблицу отсортиованную по убыванию кол-ва заказов 
orders_count.sort_values(by='transaction_id', ascending=False).head(10)
# Out:
#      visitor_id  transaction_id
# 908  3967698036               3
# 55    249864742               3
# 478  2108163459               3
# 687  2988190573               3
# 890  3908431265               3
# 138   611059232               3
# 632  2742574263               3
# 157   678354126               2
# 323  1404560065               2
# 452  1985475298               2

# %%
# серия из чисел от 0 до количества наблюдений в orders_count 
x_values = pd.Series(range(0, len(orders_count)))
# зададим размеры графика  
plt.figure(figsize=(12,8)) 
#построим график 
plt.scatter(x_values, orders_count['transaction_id'])  
# зададим описание графика 
plt.ylabel('Кол-во заказов') 
plt.xlabel('Кол-во пользователей') 
plt.title('Распределение по кол-ву сделанных заказов') 
plt.show()

# %% [markdown]
# Больше всего пользователей с 1 или 2 заказами, остальные довольно редкие.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей.

# %%
print(np.percentile(orders_count['transaction_id'], [95, 99]))
# Out:
# [1. 2.]

# %% [markdown]
# Получаем следующий результат:
#
# не более 5 % совершили не больше 1 заказа
# не более 1 % совершили не больше 2х заказов
#
# Устанавим границу по колличеству заказов на пользователя в 2 шт., заключим её в переменную:

# %%
more_orders = 2

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Перцентали выбраны верно. Но скорее всего, после обнаружения пользователей, которые вошли в обе группы (что не совсем верно) границы выбросов изменятся. Еще раз перепроверь свое решение после дополнения части с предобработкой.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сергей, судя по результату границы не изменились..
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Мы смотрим по не очищенному датафрейму.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   да, теперь изменилось
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.3</b>
#
#   ✔️ Количество заказов сократилось заметно, а вот чек не сильно уменьшился.
# </div>

# %% [markdown]
# ### Построим точечный график стоимостей заказов

# %%
orders_cleaned[['visitor_id', 'revenue']].sort_values(by='revenue', ascending=False).head(10)
# Out:
#       visitor_id  revenue
# 425   1920142716  1294500
# 1196  2108080724   202740
# 1136  1307669133    92550
# 744    888512513    86620
# 743   4133034833    67990
# 1103  1164614297    66350
# 1099   148427295    65710
# 949    887908475    60450
# 940   4003628586    58550
# 131   2254586615    53904

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))
plt.scatter(x_values, orders['revenue']) 
plt.xlabel('Пользователи')
plt.ylabel('Стоимость заказов')
plt.title("Стоимости заказов")
plt.show()

# %% [markdown]
# На графике видим 2 выброса. Посчитаем 95-й и 99-й перцентили стоимости заказов.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов

# %%
print(np.percentile(orders_cleaned['revenue'] , [95, 99]))
# Out:
# [26785. 53904.]

# %% [markdown]
# Не более 5% пользователей оформили заказы на сумму не более 26 785.
# 1% пользователей оформили заказы на сумму не более 53 904.

# %%
to_expensive_order  = 30000

# %%
print(orders_cleaned.head(10))
# Out:
#     transaction_id  visitor_id       date  revenue group
# 0       3667963787  3312258926 2019-08-15     1650     B
# 1       2804400009  3642806036 2019-08-15      730     B
# 3       3797467345  1196621759 2019-08-15     9759     B
# 4       2282983706  2322279887 2019-08-15     2308     B
# 5        182168103   935554773 2019-08-15     2210     B
# 6        398296753  2900797465 2019-08-15     1860     B
# 7       2626614568    78758296 2019-08-15     1044     A
# 8       1576988021   295230930 2019-08-15    13710     A
# 9       1506739906  1882260405 2019-08-15     1855     B
# 10      3649131742   879864040 2019-08-15     4008     A

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Здесь тоже границы выбросов должны скорректироваться.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сергей, судя по результату тут тоже без изменений
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Мы смотрим по не очищенному датафрейму.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   получилось!
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %%
# таблицы с данными по заказам на каждого пользователя
orders_by_users_a = orders_cleaned[orders_cleaned['group']=='A'].groupby('visitor_id')['transaction_id'].nunique().reset_index()
orders_by_users_a.columns=['visitors_id','orders']

orders_by_users_b = orders_cleaned[orders_cleaned['group']=='B'].groupby('visitor_id')['transaction_id'].nunique().reset_index()
orders_by_users_b.columns=['visitors_id','orders'] 

display(orders_by_users_a.head()) 
display(orders_by_users_b.head())
# Out:
#    visitors_id  orders
# 0     11685486       1
# 1     54447517       1
# 2     66685450       1
# 3     78758296       1
# 4     85103373       1
#    visitors_id  orders
# 0      5114589       1
# 1      6958315       1
# 2     39475350       1
# 3     47206413       1
# 4     48147722       1

# %% [markdown]
# Объявим переменные, в которых пользователям с заказами будет соответствовать число заказов, а пользователям без заказов — нули.

# %%
sampleA = pd.concat(
    [
        orders_by_users_a['orders'],
        pd.Series(0, 
                  index=np.arange
                  (visitors[visitors['group']=='A']['visitors'].sum() - len(orders_by_users_a['orders'])
                  ),
                  name='orders'
                 )
    ],
    axis=0)

sampleB = pd.concat(
    [
        orders_by_users_b['orders'],
        pd.Series
        (0,
         index=np.arange(
             visitors[visitors['group']=='B']['visitors'].sum() - len(orders_by_users_b['orders'])
         ),
         name='orders'
        )
    ],
    axis=0)

# %% [markdown]
# **H0:** Различий в количестве заказов между группами нет
#
# **H1:** Различия в количестве заказов между группами есть

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ У нас  количество заказов.
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Нулевая и альтернативная гипотезы сформулированы.
#
# Сами гипотезы обычно обозначают так:
# - H0 - Нет  различий ....
# - H1 - Есть различия ....
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   поправила
# </div>

# %%
result_1 = stats.mannwhitneyu(sampleA, sampleB)[1] 
#задаим значение aplha
alpha = 0.05
#введем значение p-value
print(f'Значение p-value : {result_1}')
# условный оператор с выводом строки с ответом
if result_1 < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")  
print('Средняя конверсия группы А: {:.1%}'.format(sampleA.mean()))
print('Средняя конверсия группы B: {:.1%}'.format(sampleB.mean()))  
print('Отношение конверсии В к А: {0:.3f}'.format(sampleB.mean()/sampleA.mean()-1))
# Out:
# Значение p-value : 0.011018084110014696
# Отвергаем нулевую гипотезу
# Средняя конверсия группы А: 2.5%
# Средняя конверсия группы B: 2.9%
# Отношение конверсии В к А: 0.160

# %% [markdown]
# P-value меньше заданного значения alpha - отвергаем нулевую гипотезу, следовательно верно утвеждение о том, что различия в конверсиях есть.
#
# Отношение конверсии группы В к А 0.160, что можно интропритировать как относительный прирост в ~16%.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Верно выбран сам тест и верно проинтерпретированы  его результаты!
#
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# Сформулируем гипотезы:
#
# **Н0:** Различий в средних чеках между группами нет
#
# **Н1:** Различия в средних чеках между группами есть

# %%
print('P-value:','{0:.3f}'.format(stats.mannwhitneyu(orders_cleaned[orders_cleaned['group']=='A']['revenue'], orders_cleaned[orders_cleaned['group']=='B']['revenue'])[1]))
print('Относительные различия:','{0:.3f}'.format(orders_cleaned[orders_cleaned['group']=='B']['revenue'].mean()/orders_cleaned[orders_cleaned['group']=='A']['revenue'].mean()-1))
# Out:
# P-value: 0.829
# Относительные различия: 0.287

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# P-value значительно больше 0.05 (заданного значения alpha), следовательно нулевую гипотезу не отвергаем и сследовательно верно утвеждение о том, что различий в средних чеках между группами нет. Группа B показывает средний чек на 28.7% выше, чем группа A. Однако это изменение не является статистически значимым (p-value > 0.05).
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ По результатам теста, как правило, пишут принимаем или отвергаем нулевую гипотезу. С одной стороны говорим " статистически значимых отличий в среднем чеке между группами нет.", но потом говорим, что "Относительное различие между чеками около 26%". Выводы немного противоречат друг другу. Тут лучше изменить интерпретацию: наблюдаемое различие в 26% не является стат. значимым... и .т.д.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   переписала вывод, если не против, в своем ключе
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Так вывод звучит корректней.
#
# Тут все просто. Раз теcт показал, что нет стат значимой разницы между группами - то каково бы различие чека не было, оно не будет являться стат. значимым (у нас тут выбросы дают большое различие чеков, но их всего несколько и на общее различие среднего чека по группам они не влияют)
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным

# %% [markdown]
# кол-во > 2, переменная more_orders
# сумма > 30000, переменная to_expensive_order

# %%
# собираем пользователей с большим количеством заказов 
many_orders = pd.concat(
    [
        orders_by_users_a[orders_by_users_a['orders'] > more_orders]['visitors_id'],
        orders_by_users_b[orders_by_users_b['orders'] > more_orders]['visitors_id'],
    ],
    axis=0,
)

# собираем пользователей со слишком дорогими заказами
expensive_orders = orders_cleaned[orders_cleaned['revenue'] > to_expensive_order]['visitor_id']

# объединяем всё в один датафрейм 
abnormal_users = (
    pd.concat([many_orders, expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormal_users.head(5))
print(' ')
print('Кол-во анамальных пользователей: ', abnormal_users.shape[0])
# Out:
# 1099    148427295
# 928     204675465
# 33      249864742
# 684     358944393
# 648     382846391
# dtype: int64
#
# Кол-во анамальных пользователей:  49

# %%
#отфильтруем данные в группе А 
sampleAFiltered = pd.concat(
    [
        orders_by_users_a[
            np.logical_not(orders_by_users_a['visitors_id'].isin(abnormal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group']=='A']['visitors'].sum() - len(orders_by_users_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

#отфильтруем данные в группе В
sampleBFiltered = pd.concat(
    [
        orders_by_users_b[
            np.logical_not(orders_by_users_b['visitors_id'].isin(abnormal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group']=='B']['visitors'].sum() - len(orders_by_users_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
print('P-value:','{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Относительные различия:','{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# P-value: 0.010
# Относительные различия: 0.187

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  P-value меньше 0.05 (заданного значения alpha), следовательно нулевую гипотезу отвергаем и следовательно верно утвеждение о том, что различий в средних чеках между группами нет.
# </div>

# %% [markdown]
# Как и в случае с сырым данными, статистическая значимость достигнута. Сегмент В лучше сегмента А.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Принимаем или отвергаем нулевую гипотезу?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  поправила выше
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ И тут отвергаем нулевую гипотезу.
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders_cleaned[
                np.logical_and(
                    orders_cleaned['group'] == 'A',
                    np.logical_not(orders_cleaned['visitor_id'].isin(abnormal_users)),
                )
            ]['revenue'],
            orders_cleaned[
                np.logical_and(
                    orders_cleaned['group'] == 'B',
                    np.logical_not(orders_cleaned['visitor_id'].isin(abnormal_users)),
                )
            ]['revenue'],
        )[1]
    )
)

# Относительное изменение среднего чека для групп A и B
print(
    "{0:.3f}".format(
        orders_cleaned[
            np.logical_and(
                orders_cleaned['group'] == 'B',
                np.logical_not(orders_cleaned['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        / orders_cleaned[
            np.logical_and(
                orders_cleaned['group'] == 'A',
                np.logical_not(orders_cleaned['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.741
# -0.027

# %% [markdown]
# Н0: Различий в средних чеках между группами нет
#
# Н1: Различия в средних чеках между группами есть

# %% [markdown]
# Значение p-value : 0.741
# P-value значительно больше 0.05 (заданного значения alpha), следовательно нулевую гипотезу не отвергаем и следовательно верно утвеждение о том, что различий в средних чеках между группами нет.
# Разница между сегментами сократилась с 28,7% до -27%. После удаления выбросов в данных меньше шума.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>В обоих тестах p-value выше порога значимости 0.05, поэтому нулевая гипотеза (H₀) о том, что различий в средних чеках между группами нет, не отвергается.
# Даже если относительные различия в среднем чеке есть (на 25.9% больше в одном случае и на 2% меньше в другом), эти различия незначимы статистически, что подтверждается высокими значениями p-value.</b>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Как поступаем с нулевой гипотезой? И обрати, пожалуйста, внимание на выводы: в начале мы можем говорить о наблюдаемых различиях, а потом сказать - являются ли они стат. значимыми или нет.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  поправила выше
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Верно.
# </div>

# %% [markdown]
# Выводы и имеющиеся факты:
# Есть статистически значимое различие по конверсии между группами как по сырым данным, так и после фильтрации аномалий.
#
# По сырым данным нет статистически значимого различия по среднему чеку между группами, как и после удаления выбросов.
#
# График различия конверсии между группами сообщает, что результаты группы B лучше группы A: имеют тенденцию к росту, либо зафиксировались около среднего значения.
#
# График различия среднего чека колеблется: он-то и позволил вам найти аномалии. Сделать из этого графика определённые выводы нельзя.
#
# Вариант решения -  остановить тест, признать победу группы В.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  Верно! Тут тест окрасился только на половину - `по количеству заказов`. Но это тоже хорошо, т.к. стат.значимой разницы по среднему чеку нет (чек не увеличился, но и не уменьшился) то при возросшем количестве заказов с сохранившимся средним чеком выручка будет так-же расти. И значит мы заканчиваем анализ A/B-теста - он оказался успешным!
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#
#   📃 Проверить корректность разбиения пользователей на группы.
#
#   📃 Дооформить графики, вывести название графика и подписать оси.
#
#   📃 Пересмотреть выбросы по количеству и стоимости заказов.
#
#   📃 Проверить выводы теста среднего чека по сырым и очищенным данным.
#
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится.
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#
#   📃 Проверить корректность разбиения пользователей на группы.
#
#   📃 Пересмотреть выбросы по количеству и стоимости заказов.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#  кажется теперь в порядке?
# </div>
